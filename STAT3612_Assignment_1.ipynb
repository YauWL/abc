# %% [markdown]
# Yau Wai Lam 3035282059

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv("/content/drive/My Drive/HKU File/Year 5 SEM 1/STAT 3612/Assignment/HelocData.csv")

# %%
import numpy as np
import matplotlib.pyplot as plt
x = 'x1','x2','x3','x4','x5','x6','x7','x8','x9','x10','x11','x12','x13','x14','x15','x16','x17','x18','x19','x20','x21','x22','x23'
y = sum(df.x1<0),sum(df.x2<0),sum(df.x3<0),sum(df.x4<0),sum(df.x5<0),sum(df.x6<0),sum(df.x7<0),sum(df.x8<0),sum(df.x9<0),sum(df.x10<0),sum(df.x11<0),sum(df.x12<0),sum(df.x13<0),sum(df.x14<0),sum(df.x15<0),sum(df.x16<0),sum(df.x17<0),sum(df.x18<0),sum(df.x19<0),sum(df.x20<0),sum(df.x21<0),sum(df.x22<0),sum(df.x23<0)
plt.bar(x,y)
plt.xlabel('Feature')
plt.ylabel('Frequency')
plt.show()

# %%
X = df.drop('RiskFlag',axis='columns')
Y = df[['RiskFlag']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=np.random.seed(3035282059))

# %%
X_train = X_train[X_train>=0]

# %%
X_train=X_train.fillna(X_train.mean())

# %%
df_train = pd.concat([Y_train, X_train], axis=1, sort=False)

# %%
df_train[['x1','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x2','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x3','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x4','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x5','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x6','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x7','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x8','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x9','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x10','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x11','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x12','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x13','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x14','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x15','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x16','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x17','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x18','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x19','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x20','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x21','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x22','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
df_train[['x23','RiskFlag']].boxplot(by='RiskFlag')
plt.title('')
plt.show()

# %%
Y_train = Y_train.replace('Good',1)
Y_train = Y_train.replace('Bad',0)
Y_test = Y_test.replace('Good',1)
Y_test = Y_test.replace('Bad',0)

# %%
import statsmodels.api as sm
X1 = sm.add_constant(X_train)
lm = sm.OLS(Y_train,X1).fit()
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               RiskFlag   R-squared:                       0.247
# Model:                            OLS   Adj. R-squared:                  0.245
# Method:                 Least Squares   F-statistic:                     119.0
# Date:                Sun, 06 Oct 2019   Prob (F-statistic):               0.00
# Time:                        13:42:58   Log-Likelihood:                -4878.3
# No. Observations:                8367   AIC:                             9805.
# Df Residuals:                    8343   BIC:                             9973.
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.7433      0.080     -9.296      0.000      -0.900      -0.587
# ...

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train[['x1','x4','x5','x15','x18']], Y_train) #top 5 t-value
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
print(model.intercept_)
print(model.coef_)
# Out:
# [-6.82728203]
# [[ 0.08089882  0.00728078  0.02561882  0.0537613  -0.010012  ]]

# %%
model.score(X_test[['x1','x4','x5','x15','x18']], Y_test)
# Out:
# 0.719885277246654
